# %%
#%load_ext autoreload
# %reload_ext autoreload
# %autoreload 2

# %%
from test_public import *
test_personal_info()
test_smith_normal_form()
test_invariant_factors()
test_is_trivial()
test_is_cyclic()
test_is_free()
test_rank()
test_is_finite()
test_size()
test_ord()
test_tor()
test_zero_dim()
# Out:
# badeda0e705110c72680b8a29d4828cb
